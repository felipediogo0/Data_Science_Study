# %% [markdown]
# <h1><center>Extraindo Meus Dados Gerais do Strava

# %% [markdown]
# Primeiro vamos importar o arquivo onde estão as informações, em formato texto, neste caso csv.

# %%
import pandas as pd
import datetime as dt

df = pd.read_csv('./activities.csv')
df
# Out:
#      Activity ID              Activity Date                     Activity Name  \
# 0     2547543484  Jul 20, 2019, 10:55:37 AM  Vista chinesa X Parque da Tijuca
# 1     3234413368  Mar 30, 2020, 11:11:26 AM      Passeio da Nina - 30/03/2020
# 2     3237939172  Mar 31, 2020, 11:11:55 AM           Passeio Nina 31/03/2020
# 3     3241878609   Apr 1, 2020, 11:15:48 AM        Passeio da Nina 01/04/2020
# 4     3245830966   Apr 2, 2020, 11:03:56 AM        Passeio da Nina 02/04/2020
# ..           ...                        ...                               ...
# 893   7354998372   Jun 23, 2022, 9:32:33 AM       Passeio do Chico 23/06/2022
# 894   7828297170   Sep 18, 2022, 1:06:02 PM                           Cristo
# 895   7838155401  Sep 20, 2022, 11:57:36 AM                         Caminhada
# 896   7848612315  Sep 22, 2022, 10:39:08 AM                          Cristo 2
# 897   7853768776  Sep 23, 2022, 10:53:53 AM             Caminhada / 'Sprint'
#
#     Activity Type                               Activity Description  \
# 0             Run                                                NaN
# 1            Walk      Passeio bem tranquilo com a Nina Linda... 🥰😍🐕
# 2            Walk                                                NaN
# 3            Walk  Mais um passeio muito gostoso com a Nina... ❤️🥰🐶🐕
# 4            Walk                                                NaN
# ..            ...                                                ...
# 893          Walk                                                NaN
# 894           Run                                                NaN
# 895          Walk                                                NaN
# 896          Walk                                                NaN
# 897          Walk                                                NaN
#
#      Elapsed Time  Distance  Max Heart Rate  Relative Effort  Commute  ...  \
# 0            2354      7.34             NaN              NaN    False  ...
# 1            3824      3.31             NaN              NaN    False  ...
# 2            4071      3.74             NaN              NaN    False  ...
# 3            4235      2.95             NaN              NaN    False  ...
# 4            3649      2.49             NaN              NaN    False  ...
# ..            ...       ...             ...              ...      ...  ...
# 893          3739      4.48             NaN              NaN    False  ...
# 894          2440      6.50             NaN              NaN    False  ...
# 895          1843      4.19             NaN              NaN    False  ...
# 896          2562      6.21             NaN              NaN    False  ...
# 897          2616      6.31             NaN              NaN    False  ...
#
#      Weather Ozone  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 893            NaN
# 894            NaN
# 895            NaN
# 896            NaN
# 897            NaN
#
#     <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.jump_count">Jump Count</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.total_grit">Total Grit</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_flow">Avg Flow</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                0.0
# 894                                                0.0
# 895                                                0.0
# 896                                                0.0
# 897                                                0.0
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                           1.200262
# 894                                           2.664402
# 895                                           2.277548
# 896                                           2.426401
# 897                                           2.415390
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                        2141.000000
# 894                                         242.500000
# 895                                         206.899994
# 896                                         226.000000
# 897                                         189.500000
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_distance">Newly Explored Distance</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.newly_explored_dirt_distance">Newly Explored Dirt Distance</span>  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#      <span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.sport_type">Sport Type</span>
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
# [898 rows x 84 columns]

# %%
#df.columns.tolist()
#print(list(df.columns))

# %%
df = df.dropna(how='all',axis=1)

# %% [markdown]
# #Retira todas as colunas (axis=1), onde <b>todos</b> os valores são NaN/Nulo.

# %%
df = df.drop(['Calories',
 'Perceived Exertion',
 'Prefer Perceived Exertion',
 'Perceived Relative Effort'], axis=1)

# %% [markdown]
# #Fui retirando as colunas que não seriam úteis no momento.

# %%
df = df.drop(['Commute',
 'Filename',
 'Athlete Weight',
 'Elapsed Time.1'],axis=1)

# %%
df = df.drop(['Activity Type'],axis=1)

# %%
df = df.drop(['Activity Name'],axis=1)

# %%
df = df.drop(['Activity Description'],axis=1)

# %%
df = df.drop(['<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.flagged">Flagged</span>',
 '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.avg_elapsed_speed">Avg Elapsed Speed</span>',
 '<span class="translation_missing" title="translation missing: en-US.lib.export.portability_exporter.activities.horton_values.dirt_distance">Dirt Distance</span>'],axis=1)

# %%
df = df.drop(['Commute.1',
 'From Upload',
 'Grade Adjusted Distance'],axis=1)

# %%
df = df.drop(['Distance.1'],axis=1)

# %%
df = df.drop(['Max Grade', 'Average Grade'],axis=1)

# %% [markdown]
# #Terminei de remover as colunas e imprimi um Excel do Data Frame.

# %%
#df.to_excel('Strava_activities_py.xlsx')

# %% [markdown]
# ================>>><<<<<>>>>><====================================>

# %% [markdown]
# #A Tabela que tinha 84 colunas, agora está com 11.

# %% [markdown]
# #O Elapse Time e o moving Time estão em segundos, então, é preciso converter para horas, minutos e Segundos

# %% [markdown]
# #Eu vou dividir o Data Frame em algumas tabelas, utilizando o 'Activity ID' como identificador para fazer as relações entre as tabelas no Power BI

# %%
df_time = pd.DataFrame(columns=['Activity ID','Activity Date','Elapsed Time','Moving Time'])
df_time['Activity ID'],df_time['Activity Date'], df_time['Elapsed Time'], df_time['Moving Time'] = df['Activity ID'],df['Activity Date'],df['Elapsed Time'],df['Moving Time']
df_time['Elapsed HMS'] = pd.to_timedelta(df_time['Elapsed Time'], unit='S')
df_time['Moving HMS'] = pd.to_timedelta(df_time['Moving Time'], unit='s')

# %% [markdown]
# #Convertido o tempo total e o tempo em movimento. Estavam em segundos e agora no formato 'Total' D/M/A-H:M:S

# %% [markdown]
# O tempo está em segundos, então, podemos alterar para o formato H:M:S
# Já, as velocidades não estão em Km/h, nem em m/s - > para este caso, deveríamos multiplicar/dividir por 3,6
# Caso esteja em kts(Nó) multiplicamos por 1,852
# Caso seja mph multiplicamos por 1.61

# %%
df_speed = pd.DataFrame(columns=['Activity ID','Max Speed','Average Speed'])
df_speed['Activity ID'], df_speed['Max Speed'], df_speed['Average Speed'] = df['Activity ID'],df['Max Speed'],df['Average Speed']

# %%
df_distance = pd.DataFrame(columns=['Activity ID', 'Distance'])
df_distance['Activity ID'], df_distance['Distance'] = df['Activity ID'], df['Distance']

# %%
df_height = pd.DataFrame(columns=['Activity ID','Elevation Gain','Elevation Loss','Elevation Low','Elevation High'])
df_height['Activity ID'], df_height['Elevation Gain'], df_height['Elevation Loss'], df_height['Elevation Low'], df_height['Elevation High'] = df['Activity ID'], df['Elevation Gain'], df['Elevation Loss'], df['Elevation Low'], df['Elevation High']
df_speed

# %% [markdown]
# #Por hora acredito que é isso com Python, agora vou importar todas as planilhas no <b>Power Bi</b> e Iniciar o relatório.

# %%
df_speed = df_speed.sort_values(['Max Speed'], ascending=False)
display(df_speed)

# %%
df_description = pd.DataFrame(columns=['Activity ID', 'Activity Name', 'Activity Description'])
df_description['Activity ID'], df_description['Activity Name'], df_description['Activity Description'] = df['Activity ID'], df['Activity Name'], df['Activity Description']

# %% [markdown]
# ================>>>>>>>>>>>><<<<<<<<<<<<<<<<>>>>>>>>>><<<<<<<<<<<>>>>>>>>>>>>>>>>><=============================================
