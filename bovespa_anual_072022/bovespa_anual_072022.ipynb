# %%
import pandas as pd

# %%
df = pd.read_csv('./arquivos/bovespa_anual1.csv')
df = df.drop('Unnamed: 0',axis=1)
df.sort_values(by = ['preco_abertura'], inplace=True)
df_ibov = df[df['cod_acao'] == 'IBOV11']
df = df.drop(df_ibov.index)
df
# Out:
#        data_pregao cod_acao      nome_emp  preco_abertura  preco_maximo  \
# 37337     20220315   E1DU34  NEW ORIENTAL            27.0          37.0
# 36568     20220314   E1DU34  NEW ORIENTAL            33.0          33.0
# 48149     20220404   E1DU34  NEW ORIENTAL            37.0          40.0
# 51279     20220408   E1DU34  NEW ORIENTAL            37.0          39.0
# 38883     20220317   E1DU34  NEW ORIENTAL            39.0          40.0
# ...            ...      ...           ...             ...           ...
# 6116      20220113   ASML34     ASML HOLD        420000.0      428500.0
# 2382      20220106   ASML34     ASML HOLD        424845.0      433300.0
# 1612      20220105   ASML34     ASML HOLD        432700.0      434866.0
# 59        20220103   ASML34     ASML HOLD        448440.0      450217.0
# 818       20220104   ASML34     ASML HOLD        450500.0      450500.0
#
#        preco_minimo  preco_fechamento  qtd_negocios  vol_financeiro
# ...
